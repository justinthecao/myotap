# %%
# !pip install "stable-baselines3[extra]" --quiet
# !pip install tqdm --quiet
# %env MUJOCO_GL=enable
from myosuite.utils import gym
from showvid import show_video
import skvideo.io
import numpy as np
import os
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
# Out:
# env: MUJOCO_GL=enable

# %% [markdown]
# # MyoFingerReach example

# %%
env = gym.make('myoFingerReachFixed-v0')

model = PPO("MlpPolicy", env, verbose=0)
model.learn(total_timesteps=100000)
model.save("Reach_policy")

# %%
# evaluate policy
all_rewards = []
for _ in tqdm(range(20)): # 20 random targets
  ep_rewards = []
  done = False
  obs, _ = env.reset()
  for _ in range(40):
      # get the next action from the policy
      action, _ = model.predict(obs)
      # take an action based on the current observation
      obs, reward, done, _, info = env.step(action)
      ep_rewards.append(reward)
  all_rewards.append(np.sum(ep_rewards))
print(f"Average reward: {np.mean(all_rewards)} over 20 episodes")

# %%
env.reset()
frames = []
obs, _ = env.reset()
for _ in tqdm(range(1000)):
    # Predict the best action based on the current observation
    action, _ = model.predict(obs)
    # Render the current frame from the environment
    frames.append(env.sim.renderer.render_offscreen(
                        width=400,
                        height=400,
                        camera_id=-1))
    # Take the action and get the next observation
    obs, _, done, _, _ = env.step(action)
env.close()

# %%
os.makedirs('videos', exist_ok=True)
# make a local copy
skvideo.io.vwrite('videos/Reach.mp4', np.asarray(frames),outputdict={"-pix_fmt": "yuv420p"})

# show in the notebook
show_video('videos/Reach.mp4')

# %%
from myosuite.utils import gym
import matplotlib.pyplot as plt
env = gym.make('MyoHandBowlFixed-v0')

# find geometries with ID == 1 which indicates the skins
geom_1_indices = np.where(env.sim.model.geom_group == 1)
# Change the alpha value to make it transparent
env.sim.model.geom_rgba[geom_1_indices, 3] = 0
env.reset()
frames = []
for _ in range(100):
    env.playback()
    frames.append(env.sim.renderer.render_offscreen(
                        width=400,
                        height=400,
                        camera_id=2))
env.close()
# Out:
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.sim to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.sim` for environment variables or `env.get_wrapper_attr('sim')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.playback to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.playback` for environment variables or `env.get_wrapper_attr('playback')` that will search the reminding wrappers.
#   logger.warn(

# %%
import os
import skvideo.io
os.makedirs('videos', exist_ok=True)
# make a local copy
skvideo.io.vwrite('videos/BowlMyo.mp4', np.asarray(frames),outputdict={"-pix_fmt": "yuv420p"})

# show in the notebook
show_video('videos/BowlMyo.mp4')
# Out:
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# <video autoplay width=400 controls><source src="data:video/mp4;base64,..."></video>

# %% [markdown]
# # MyoDm example

# %%
import numpy as np
from myosuite.utils import gym
import os

env = gym.make('MyoHandBowlFixed-v0')
env.reset()

from stable_baselines3 import PPO
model = PPO("MlpPolicy", env, verbose = 1, device = 'cpu')
# model.learn(total_timesteps=10000)
# to train to convergence use more iterations e.g.
model.learn(total_timesteps=100000)
model.save("inspect_policy")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | -1       |
# | time/              |          |
# |    fps             | 552      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1        |
# |    ep_rew_mean          | -1       |
# | time/                   |          |
# |    fps                  | 503      |
# |    iterations           | 2        |
# |    time_elapsed         | 8        |
# |    total_timesteps      | 4096     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -63.9    |
# |    explained_variance   | nan      |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 10       |
# |    policy_gradient_loss | 0        |
# |    std                  | 1        |
# |    value_loss           | 0.0713   |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -1         |
# | time/                   |            |
# |    fps                  | 485        |
# |    iterations           | 3          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.16973068 |
# |    clip_fraction        | 0.662      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -63.8      |
# |    explained_variance   | 0.551      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.116     |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.111     |
# |    std                  | 0.998      |
# |    value_loss           | 1.9e-15    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 479         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.054275572 |
# |    clip_fraction        | 0.478       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.7       |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0913     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0794     |
# |    std                  | 0.995       |
# |    value_loss           | 1.24e-15    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -1         |
# | time/                   |            |
# |    fps                  | 477        |
# |    iterations           | 5          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.03147876 |
# |    clip_fraction        | 0.36       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -63.5      |
# |    explained_variance   | 0.851      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0605    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0565    |
# |    std                  | 0.993      |
# |    value_loss           | 9.04e-16   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 6           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.024182014 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.4       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0309     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0387     |
# |    std                  | 0.992       |
# |    value_loss           | 5.61e-16    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 473         |
# |    iterations           | 7           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015863856 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.3       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.027      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0255     |
# |    std                  | 0.99        |
# |    value_loss           | 3.63e-16    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 473         |
# |    iterations           | 8           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012610268 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.2       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00967    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.988       |
# |    value_loss           | 2.36e-16    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 473         |
# |    iterations           | 9           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008764594 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.2       |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00989    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.988       |
# |    value_loss           | 1.17e-16    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 10          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010224322 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.2       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0122     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00878    |
# |    std                  | 0.987       |
# |    value_loss           | 1.07e-16    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 11          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011912221 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.1       |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00648    |
# |    std                  | 0.987       |
# |    value_loss           | 8.15e-17    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 12          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013849414 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.1       |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00995    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00523    |
# |    std                  | 0.987       |
# |    value_loss           | 4.23e-17    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 13          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009244495 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.1       |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00229    |
# |    std                  | 0.986       |
# |    value_loss           | 1.39e-17    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 14          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.012030583 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63.1       |
# |    explained_variance   | 0.00391     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00236    |
# |    std                  | 0.986       |
# |    value_loss           | 1.39e-17    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 15          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011957175 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63         |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00199    |
# |    std                  | 0.985       |
# |    value_loss           | 1.56e-16    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 16          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.016890813 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -63         |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00978    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00121    |
# |    std                  | 0.984       |
# |    value_loss           | 6.94e-18    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -1           |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 17           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0004957105 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -63          |
# |    explained_variance   | nan          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0            |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0            |
# |    std                  | 0.984        |
# |    value_loss           | 0            |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 18          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008887765 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.9       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.000309   |
# |    std                  | 0.984       |
# |    value_loss           | 1.73e-18    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 19          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014386071 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.9       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.000787   |
# |    std                  | 0.984       |
# |    value_loss           | 5.2e-18     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 20          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011522444 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.9       |
# |    explained_variance   | 0.000488    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.000278   |
# |    std                  | 0.984       |
# |    value_loss           | 1.73e-18    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 21          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.012733847 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.9       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.000749   |
# |    std                  | 0.984       |
# |    value_loss           | 5.2e-18     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -1         |
# | time/                   |            |
# |    fps                  | 466        |
# |    iterations           | 22         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.04225812 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -62.9      |
# |    explained_variance   | 0.000977   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0          |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.000581  |
# |    std                  | 0.984      |
# |    value_loss           | 3.47e-18   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -1            |
# | time/                   |               |
# |    fps                  | 465           |
# |    iterations           | 23            |
# |    time_elapsed         | 101           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00019479575 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -62.9         |
# |    explained_variance   | nan           |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0             |
# |    n_updates            | 220           |
# |    policy_gradient_loss | 0             |
# |    std                  | 0.984         |
# |    value_loss           | 0             |
# -------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1        |
# |    ep_rew_mean          | -1       |
# | time/                   |          |
# |    fps                  | 465      |
# |    iterations           | 24       |
# |    time_elapsed         | 105      |
# |    total_timesteps      | 49152    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -62.9    |
# |    explained_variance   | nan      |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 230      |
# |    policy_gradient_loss | 0        |
# |    std                  | 0.984    |
# |    value_loss           | 0        |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -1         |
# | time/                   |            |
# |    fps                  | 464        |
# |    iterations           | 25         |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.09867945 |
# |    clip_fraction        | 0.445      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -62.9      |
# |    explained_variance   | 0.000977   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0          |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.000448  |
# |    std                  | 0.983      |
# |    value_loss           | 3.47e-18   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -1         |
# | time/                   |            |
# |    fps                  | 464        |
# |    iterations           | 26         |
# |    time_elapsed         | 114        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01563548 |
# |    clip_fraction        | 0.333      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -62.8      |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0          |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.000193  |
# |    std                  | 0.982      |
# |    value_loss           | 1.73e-18   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -1            |
# | time/                   |               |
# |    fps                  | 464           |
# |    iterations           | 27            |
# |    time_elapsed         | 119           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 3.5142846e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -62.9         |
# |    explained_variance   | nan           |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0             |
# |    n_updates            | 260           |
# |    policy_gradient_loss | 0             |
# |    std                  | 0.982         |
# |    value_loss           | 0             |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 28          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.020988394 |
# |    clip_fraction        | 0.471       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.8       |
# |    explained_variance   | 0.000488    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000199   |
# |    std                  | 0.982       |
# |    value_loss           | 1.73e-18    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -1            |
# | time/                   |               |
# |    fps                  | 464           |
# |    iterations           | 29            |
# |    time_elapsed         | 127           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00083230174 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -62.9         |
# |    explained_variance   | nan           |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0             |
# |    n_updates            | 280           |
# |    policy_gradient_loss | 0             |
# |    std                  | 0.982         |
# |    value_loss           | 0             |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 30          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.019505743 |
# |    clip_fraction        | 0.418       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.8       |
# |    explained_variance   | 0.000488    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000208   |
# |    std                  | 0.982       |
# |    value_loss           | 1.73e-18    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -1         |
# | time/                   |            |
# |    fps                  | 464        |
# |    iterations           | 31         |
# |    time_elapsed         | 136        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.06870071 |
# |    clip_fraction        | 0.495      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -62.8      |
# |    explained_variance   | 0.00195    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0          |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.000805  |
# |    std                  | 0.981      |
# |    value_loss           | 6.94e-18   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -1           |
# | time/                   |              |
# |    fps                  | 464          |
# |    iterations           | 32           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0032992722 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -62.8        |
# |    explained_variance   | nan          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0            |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0            |
# |    std                  | 0.981        |
# |    value_loss           | 0            |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 33          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.017120492 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.8       |
# |    explained_variance   | 0.000488    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00024    |
# |    std                  | 0.982       |
# |    value_loss           | 1.73e-18    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -1            |
# | time/                   |               |
# |    fps                  | 463           |
# |    iterations           | 34            |
# |    time_elapsed         | 150           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 2.2187072e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -62.8         |
# |    explained_variance   | nan           |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0             |
# |    n_updates            | 330           |
# |    policy_gradient_loss | 0             |
# |    std                  | 0.982         |
# |    value_loss           | 0             |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 35          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.022842787 |
# |    clip_fraction        | 0.464       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.8       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000208   |
# |    std                  | 0.982       |
# |    value_loss           | 1.73e-18    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 36          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.029783417 |
# |    clip_fraction        | 0.456       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.9       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.000202   |
# |    std                  | 0.983       |
# |    value_loss           | 1.73e-18    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 37          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005572932 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.9       |
# |    explained_variance   | nan         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0           |
# |    std                  | 0.983       |
# |    value_loss           | 0           |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1        |
# |    ep_rew_mean          | -1       |
# | time/                   |          |
# |    fps                  | 463      |
# |    iterations           | 38       |
# |    time_elapsed         | 167      |
# |    total_timesteps      | 77824    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -62.9    |
# |    explained_variance   | nan      |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 370      |
# |    policy_gradient_loss | 0        |
# |    std                  | 0.983    |
# |    value_loss           | 0        |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -1         |
# | time/                   |            |
# |    fps                  | 463        |
# |    iterations           | 39         |
# |    time_elapsed         | 172        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.03272356 |
# |    clip_fraction        | 0.528      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -62.9      |
# |    explained_variance   | 0.000488   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0          |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.000179  |
# |    std                  | 0.983      |
# |    value_loss           | 1.73e-18   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 40          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.023308815 |
# |    clip_fraction        | 0.436       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.9       |
# |    explained_variance   | 0.000488    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.000203   |
# |    std                  | 0.983       |
# |    value_loss           | 1.73e-18    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -1            |
# | time/                   |               |
# |    fps                  | 463           |
# |    iterations           | 41            |
# |    time_elapsed         | 181           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 6.0797232e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -62.8         |
# |    explained_variance   | nan           |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0             |
# |    n_updates            | 400           |
# |    policy_gradient_loss | 0             |
# |    std                  | 0.983         |
# |    value_loss           | 0             |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 42          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.019112747 |
# |    clip_fraction        | 0.491       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.8       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.03e-11    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.000333   |
# |    std                  | 0.982       |
# |    value_loss           | 1.28e-13    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -1            |
# | time/                   |               |
# |    fps                  | 464           |
# |    iterations           | 43            |
# |    time_elapsed         | 189           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.00033780278 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -62.8         |
# |    explained_variance   | nan           |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0             |
# |    n_updates            | 420           |
# |    policy_gradient_loss | 0             |
# |    std                  | 0.982         |
# |    value_loss           | 1e-05         |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 44          |
# |    time_elapsed         | 194         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.016139396 |
# |    clip_fraction        | 0.403       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.8       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.000159   |
# |    std                  | 0.982       |
# |    value_loss           | 1.73e-18    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 45          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.051592138 |
# |    clip_fraction        | 0.412       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.8       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000162   |
# |    std                  | 0.983       |
# |    value_loss           | 1.73e-18    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -1          |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 46          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009321839 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -62.8       |
# |    explained_variance   | nan         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0           |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0           |
# |    std                  | 0.983       |
# |    value_loss           | 0           |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1        |
# |    ep_rew_mean          | -1       |
# | time/                   |          |
# |    fps                  | 463      |
# |    iterations           | 47       |
# |    time_elapsed         | 207      |
# |    total_timesteps      | 96256    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -62.8    |
# |    explained_variance   | nan      |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 460      |
# |    policy_gradient_loss | 0        |
# |    std                  | 0.983    |
# |    value_loss           | 0        |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1        |
# |    ep_rew_mean          | -1       |
# | time/                   |          |
# |    fps                  | 463      |
# |    iterations           | 48       |
# |    time_elapsed         | 212      |
# |    total_timesteps      | 98304    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -62.8    |
# |    explained_variance   | nan      |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 470      |
# |    policy_gradient_loss | 0        |
# |    std                  | 0.983    |
# |    value_loss           | 0        |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1        |
# |    ep_rew_mean          | -1       |
# | time/                   |          |
# |    fps                  | 463      |
# |    iterations           | 49       |
# |    time_elapsed         | 216      |
# |    total_timesteps      | 100352   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -62.8    |
# |    explained_variance   | nan      |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 480      |
# |    policy_gradient_loss | 0        |
# |    std                  | 0.983    |
# |    value_loss           | 0        |
# --------------------------------------

# %%
all_rewards = []
for _ in tqdm(range(20)): # 20 random targets
  ep_rewards = []
  done = False
  obs, _ = env.reset()
  for _ in range(40):
      # get the next action from the policy
      action, _ = model.predict(obs)
      # take an action based on the current observation
      obs, reward, done, _, info = env.step(action)
      ep_rewards.append(reward)
  all_rewards.append(np.sum(ep_rewards))
print(f"Average reward: {np.mean(all_rewards)} over 20 episodes")
# Out:
# C:\Users\justin\AppData\Local\Temp\ipykernel_14844\3740676958.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for _ in tqdm(range(20)): # 20 random targets
#   0%|          | 0/20 [00:00<?, ?it/s]
# Average reward: -73.99887987228114 over 20 episodes

# %%
env.reset()
# find geometries with ID == 1 which indicates the skins
geom_1_indices = np.where(env.sim.model.geom_group == 1)
# Change the alpha value to make it transparent
env.sim.model.geom_rgba[geom_1_indices, 3] = 0

env.sim.renderer.set_viewer_settings(
           render_actuator=True,
           render_tendon=True
       )


# find geometries with ID == 1 which indicates the skins
geom_1_indices = np.where(env.sim.model.geom_group == 1)
# Change the alpha value to make it transparent
env.sim.model.geom_rgba[geom_1_indices, 3] = 0

env.sim.renderer.set_viewer_settings(
           render_actuator=True,
           render_tendon=True
       )

pi = PPO.load("inspect_policy")
frames = []
for _ in range(400):
    frames.append(env.sim.renderer.render_offscreen(width=400, height=400, camera_id=5))
    o = env.get_obs()
    a = pi.predict(o)[0]
    next_o, r, done, *_, ifo = env.step(
        a
    )  # take an action based on the current observation
    
import skvideo.io
import os
os.makedirs("videos", exist_ok=True)
# make a local copy
skvideo.io.vwrite(
    "videos/inspect.mp4",

    np.asarray(frames),
    outputdict={"-pix_fmt": "yuv420p", "-r": "10"},
)
# Out:
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# ...
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())
# c:\Users\justin\miniconda3\envs\myotap\lib\site-packages\skvideo\io\ffmpeg.py:466: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   self._proc.stdin.write(vid.tostring())

# %%
show_video('videos/inspect.mp4')
# Out:
# <video autoplay width=400 controls><source src="data:video/mp4;base64,..."></video>
